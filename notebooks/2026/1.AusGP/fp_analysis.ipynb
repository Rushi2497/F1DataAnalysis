# %%
import fastf1
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from fastf1 import plotting
from src.plotset import setup_plot

setup_plot()
# Out:
# Matplotlib rcParams initialized with custom style.

# %%
fastf1.Cache.enable_cache('./f1_cache')
fastf1.Cache.get_cache_info()
# Out:
# ('./f1_cache', 2048908138)

# %%
session = fastf1.get_session(2026, 1, 'FP2')
session.load()
# Out:
# core           INFO 	Loading data for Australian Grand Prix - Practice 2 [v3.8.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# core        WARNING 	No result data for this session available on Ergast! (This is expected for recent sessions)
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# ...

# %%
session.laps.groupby('Driver')['LapNumber'].max().sort_values(ascending=False)
# Out:
# Driver
# HUL    34.0
# ALB    32.0
# HAM    32.0
# ANT    31.0
# BEA    31.0
# LEC    30.0
# LIN    30.0
# LAW    29.0
# OCO    29.0
# NOR    29.0
# RUS    28.0
# BOT    28.0
# BOR    28.0
# HAD    28.0
# COL    27.0
# PIA    26.0
# ALO    18.0
# GAS    16.0
# VER    13.0
# STR    13.0
# SAI    10.0
# PER     2.0
# Name: LapNumber, dtype: float64

# %%
session.laps.groupby('Team')['LapNumber'].count().sort_values(ascending=False)
# Out:
# Team
# Audi               62
# Ferrari            62
# Haas F1 Team       60
# Racing Bulls       59
# Mercedes           59
# McLaren            55
# Alpine             43
# Williams           42
# Red Bull Racing    41
# Aston Martin       31
# Cadillac           30
# Name: LapNumber, dtype: int64
